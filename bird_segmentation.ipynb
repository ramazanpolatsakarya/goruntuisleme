# %% [markdown]
# https://universe.roboflow.com/chirp-live-bird-feeder-stream/chirp-pa-birds

# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#   WARNING: The script filetype.exe is installed in 'C:\Users\ramazan.polat3\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script dotenv.exe is installed in 'C:\Users\ramazan.polat3\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script roboflow.exe is installed in 'C:\Users\ramazan.polat3\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\Scripts' which is not on PATH.
# ...

# %%
# !pip install --upgrade pip

# %%
# !pip install opencv-python

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import ultralytics
from roboflow import Roboflow
from ultralytics import YOLO
from IPython.display import Image

# %%
rf = Roboflow(api_key="bo4ok0B3wpoJujhaScaa")
project = rf.workspace("leem-pf8fb").project("bird-v2")
dataset = project.version(2).download("yolov8")

# %%
import yaml

data = {
        'test' :  './test/images',
        'train' :  './train/images',
        'val' :  './valid/images',
        'nc': 35,
        'names': [
            'acorn-woodpecker',
            'annas-hummingbird',
            'blue-jay',
            'blue-winged-warbler',
            'carolina-chickadee',
            'carolina-wren',
            'chipping-sparrow',
            'common-eider',
            'common-yellowthroat',
            'dark-eyed-junco',
            'eastern-bluebird',
            'eastern-towhee',
            'harris-hawk',
            'hermit-thrush',
            'indigo-bunting',
            'juniper-titmouse',
            'northern-cardinal',
            'northern-mockingbird',
            'northern-waterthrush',
            'orchard-oriole',
            'painted-bunting',
            'prothonotary-warbler',
            'red-winged-blackbird',
            'rock-pigeon',
            'rofous-crowned-sparrow',
            'ruddy-duck',
            'scarlet-tanager',
            'snow-goose',
            'song-sparrow',
            'tufted-titmouse',
            'varied-thrush',
            'white-breasted-nuthatch',
            'white-crowned-sparrow',
            'white-throated-sparrow',
            'wood-duck'
        ]
        }

# %%
with open('/content/bird-v2-2/data.yaml', 'w') as f:
    yaml.dump(data, f)

# %%
with open('/content/bird-v2-2/data.yaml', 'r') as f:
    data_yaml = yaml.safe_load(f)
    display(data_yaml)

# %%
import os

from ultralytics import YOLO


model = YOLO('yolov8n-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/bird-v2-2/data.yaml', epochs=10, imgsz=640)

# %%
model_path = '/content/runs/segment/train/weights/last.pt'

image_path = '/content/bird-v2-2/test/images/011ac2c99ea348a3a742eb184c13eb30_jpg.rf.7b1637f8d0b63d3cfa241ac6b2d25cb3.jpg'

img = cv2.imread(image_path)
H, W, _ = img.shape

model = YOLO(model_path)

results = model(img)

for result in results:
    for j, mask in enumerate(result.masks.data):

        mask = mask.numpy() * 255

        mask = cv2.resize(mask, (W, H))

        cv2.imwrite('./output.png', mask)

# %%
cap = cv2.VideoCapture(url_video)

ret = True
# read frames
while ret:
    ret, frame = cap.read()

    if ret:

        # detect objects
        # track objects
        results = model.track(frame, persist=True)

        # plot results
        # cv2.rectangle
        # cv2.putText
        frame_ = results[0].plot()

        # visualize
        cv2.imshow('frame', frame_)
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break
# Pencereyi kapat ve kamerayı serbest bırak
cap.release()
cv2.destroyAllWindows()
